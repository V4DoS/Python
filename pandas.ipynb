# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
StudentsPerformance=pd.read_csv('C:/Users/bondarenkovv/Desktop/Python/ML/Stepik course/1pandas/StudentsPerformance.csv')

# %%
StudentsPerformance=StudentsPerformance.rename(columns={
'parental level of education' : 'parental_level_of_education',
'test preparation course' : 'test_preparation_course',
'math score' : 'math_score',
'reading score' : 'reading_score',
'writing score' : 'writing_score'})

# %%
StudentsPerformance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
StudentsPerformance.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
StudentsPerformance.sort_values(by=['gender', 'reading_score'],ascending=False) # Сортировка
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 381    male        group C          associate's degree      standard
# 916    male        group E           bachelor's degree      standard
# 625    male        group D                some college      standard
# 571    male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 17   female        group B            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 601  female        group C                 high school      standard
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
StudentsPerformance.head(10)
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
StudentsPerformance.iloc[0:5 , 0:3] #от 0 до 5 строки, 0-3
# Out:
#    gender race/ethnicity parental_level_of_education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
StudentsPerformance.iloc[[0,10,20] , [2,4,-2,-1]]  #выбираем колонки сами

# %%
StudentsPerformance['math_score'].value_counts()
# Out:
# math_score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: count, Length: 81, dtype: int64

# %%
StudentsPerformance['math_score'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='math_score'>

# %%
StudentsPerformance.sort_values(by=['gender','math_score'],ascending=False).groupby('gender').head(5)        #ТОп 5 male/female   math score
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
StudentsPerformance['total_score']=StudentsPerformance.math_score+StudentsPerformance.reading_score+StudentsPerformance.writing_score
StudentsPerformance.head(5)
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
StudentsPerformance=StudentsPerformance.assign(log_score=np.log(StudentsPerformance.total_score))
StudentsPerformance.head(5)

# %%
StudentsPerformance_withname.index=['Варя','Вика','Глаша','Маша','Даша'] #Присвоение индекса

# %%
StudentsPerformance.groupby('gender').aggregate({'writing score': 'mean', 'math score' :'sum'})

# %%
StudentsPerformance_withname=StudentsPerformance.iloc[[2,4,6,8,10]]

# %%
StudentsPerformance_withname.loc[['Варя','Даша']]

# %%
my_series1=pd.Series([1,2,3],index=['Вика','Глаша','Маша'])
my_series2=pd.Series([4,5,6],index=['Ваня','Саша','Вадим'])
my_series1

# %%
pd.concat([my_series1, my_series2], axis=0)

# %%
mean_writing_score=StudentsPerformance['writing score'].mean()

# %%
mean_writing_score

# %%
StudentsPerformance.loc[StudentsPerformance.gender=='male']

# %%
StudentsPerformance.loc[StudentsPerformance['writing score']>mean_writing_score]

# %%
StudentsPerformance.groupby('lunch').aggregate({'lunch': 'count'})

# %%
StudentsPerformance.groupby('lunch')[['math score', 'reading score', 'writing score']].mean()

# %%
StudentsPerformance.groupby('lunch')[['math score', 'reading score', 'writing score']].var() #Дисперсия

# %%
StudentsPerformance.query("gender=='male' & math_score > 70  ")

# %%
writing_score_query=74

# %%
StudentsPerformance.query("writing_score > @writing_score_query") #Экранирование @

# %%
StudentsPerformance.filter(like='score') #отбор всех столбцов содержащих score

# %%
StudentsPerformance.filter(like='e', axis=1) #1-Столбец, 0-Строка

# %%
my_stat =pd.read_csv('C:/Users/bondarenkovv/Desktop/Python/ML/Stepik course/1/my_stat1.csv')

# %%
my_stat.isna().any().sum() #Проверка если ели NAN и кол-во Nan

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({f'c_{i}': np.arange(1000)*i for i in range (100)})
df
